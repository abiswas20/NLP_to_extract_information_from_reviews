# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import sklearn
import gc

# %%
gc.get_threshold()
# Out:
# (700, 10, 10)

# %%
gc.set_threshold(100,4,4)

# %%
book_reviews=pd.read_csv('./data/pre_processed_data.csv')  #loading pickle file

# %%
book_reviews.head()  #taking a quick look at the data
# Out:
#          asin  overall  verified  \
# 0  0007444117        1     False
# 1  0007177437        4      True
# 2  0007327064        5      True
# 3  0030352401        3     False
# 4  000755236X        5      True
#
#                                           reviewText  reviewTime
# 0  I was a huge fan when the Divergent series sta...  2016-09-03
# 1                                    Excellent read.  2015-09-16
# 2  From the very beginning.. I have loved Odd Tho...  2016-07-17
# 3  A good, easy, light-hearted read--however ther...  2016-03-02
# 4  As a fan of Daniel Silva's  books, especially ...  2017-03-07

# %%
book_reviews.drop_duplicates(inplace=True) #drop any duplicate row

# %%
#Find the number of reviews for each asin number and then sort them in descending order
review_counts=book_reviews.groupby(by='asin').count()
review_counts.sort_values(by='overall',ascending=False,inplace=True)

# %%
#selecting the most reviews books for the period
most_reviewed=review_counts[['overall']].head(300).copy(deep=True)

# %%
#review_counts is a large dataframe. deleting it and then triggering garbage collection.
del review_counts
gc.collect()
# Out:
# 22

# %% [markdown]
# ---

# %%
#creating a list of most reviewed books
most_reviewed=most_reviewed.index.to_list()

# %%
most_reviewed
# Out:
# ['038568231X',
#  '0312577222',
#  '1683247353',
#  '0553418025',
#  '1503943372',
#  '1410472922',
#  '0007548672',
#  '1503934713',
#  '0099911701',
#  '0751565350',
#  '1503935310',
#  '0062409883',
#  '1101946342',
#  '030788743X',
#  '0147520762',
#  '0091955106',
#  '0143109464',
#  '0385539436',
#  'B00SB123IM',
#  '1503953386',
#  '0099740915',
#  'B017WJ5PR4',
#  '0316228532',
#  '1250158060',
#  '0545582881',
#  'B017V4IPPO',
#  '1503950255',
#  '1477848665',
#  '1910751774',
#  '0091944244',
#  '1410493547',
#  '081298840X',
#  '0143125478',
#  '0804192898',
#  '0451412656',
#  '0008220565',
#  '1491598778',
#  '0345544978',
#  '0385541198',
#  '1477829407',
#  '0340979496',
#  '0385543026',
#  'B000X1MX7E',
#  '0375434542',
#  '0529120887',
#  '0425284689',
#  '1542046599',
#  '0802407692',
#  '1503936864',
#  '0399167064',
#  '0984502203',
#  '0099664313',
#  '1455541516',
#  '0375969020',
#  '0439023521',
#  '0349407762',
#  '0316225940',
#  '1517153158',
#  '1477825576',
#  '8184776217',
#  '0525492127',
#  '1455568872',
#  '0439249546',
#  '0141378247',
#  '1477828737',
#  '000755236X',
#  '1447287967',
#  '1410493415',
#  '144947425X',
#  '0718079183',
#  '0143108867',
#  '0399179135',
#  '1477825975',
#  '1501086138',
#  '0385689225',
#  '1477824243',
#  '0099579936',
#  '0552778478',
#  '110188696X',
#  '0345542975',
#  '1542722829',
#  '1472229959',
#  '1491591846',
#  '0007155662',
#  '1410482596',
#  '1410478750',
#  '1475031904',
#  '006195070X',
#  '1442384344',
#  '0751550051',
#  '1477820019',
#  'B003156C4E',
#  '1408704617',
#  '1495179400',
#  '1503939324',
#  '1455536253',
#  '1501132938',
#  '000711835X',
#  '0385393938',
#  '1250132363',
#  'B001C4VLZQ',
#  '1477818294',
#  '1503936198',
#  '0008102147',
#  '006017322X',
#  '0060786469',
#  '0982301820',
#  '0751550019',
#  '0316055433',
#  'B000FK9M18',
#  '0316245283',
#  'B000K5THYU',
#  '1477820876',
#  '1477822089',
#  '0385677006',
#  '0143142372',
#  '1477821937',
#  '0451482212',
#  '0385541171',
#  '1444779761',
#  '1501110365',
#  '0297859382',
#  '0316225983',
#  '1503943429',
#  'B00V731OIG',
#  '1503945626',
#  '0345543254',
#  '0307989909',
#  '0718180283',
#  '0307408868',
#  '0345543017',
#  '0139357432',
#  '1473634016',
#  '144238820X',
#  '151738799X',
#  '1503933385',
#  '0062429078',
#  '0007350899',
#  '0399593489',
#  '1503950778',
#  '1896350542',
#  '0141043768',
#  '1455571156',
#  '1503952088',
#  '1623363586',
#  '1503950646',
#  '1503939308',
#  '0141192496',
#  '0399159347',
#  '1432842323',
#  '0007420412',
#  '1503941892',
#  'B00ZX99WE8',
#  'B011UNEZN8',
#  '0147525071',
#  '0735221952',
#  '0091906814',
#  '1503936805',
#  'B00V5E7YR2',
#  '1503943925',
#  '0141027126',
#  '1250109302',
#  '0525955097',
#  '0062457713',
#  '2253195103',
#  '1469984202',
#  '1878424319',
#  '1401948316',
#  '1514193159',
#  '0991677196',
#  '0385344430',
#  '0525497145',
#  '0593077393',
#  '1444775847',
#  '0062320165',
#  '1455540412',
#  '1477830812',
#  '0008272085',
#  '0765317583',
#  '0142800422',
#  '1535197722',
#  '1503938719',
#  '145558651X',
#  '0718077954',
#  '0142800376',
#  '0007378033',
#  '1477829822',
#  '1503948706',
#  '1503933547',
#  '1477822593',
#  'B00Y21VGYW',
#  '0552160962',
#  '1503953319',
#  '1503936171',
#  '1477819681',
#  '1410440478',
#  '0143129430',
#  'B00Y68O6WK',
#  '0553292587',
#  'B00A9WRH3M',
#  '0316225886',
#  '1912106949',
#  '0030565073',
#  '1786811138',
#  '0316349895',
#  '1503934152',
#  '0575081406',
#  '0099619105',
#  '1503936902',
#  '0062347268',
#  '0606371192',
#  '1503281981',
#  '0316290033',
#  '0439287197',
#  '1433524724',
#  '0061351415',
#  '1469216051',
#  '0007173156',
#  '0307747441',
#  '0778316556',
#  '0439064864',
#  '0544609719',
#  '140885788X',
#  '1503947874',
#  '0385539258',
#  '0486796647',
#  '1503936821',
#  '0812469496',
#  '0641866240',
#  '0007384289',
#  '1501200267',
#  '1447286200',
#  '0312495412',
#  '0385537859',
#  '0446568813',
#  '0316407046',
#  '1250022118',
#  '1503954064',
#  '1477820280',
#  '1477819967',
#  '034551162X',
#  '060637387X',
#  '1503952231',
#  '1408839121',
#  '0525955100',
#  '1536617636',
#  '1503942767',
#  '1780674880',
#  '0008132526',
#  '037032921X',
#  '1501180126',
#  '0060740221',
#  '0307476073',
#  '0091900212',
#  '034941078X',
#  '1683990021',
#  '0307341577',
#  '0393609391',
#  '0062372106',
#  '1250066115',
#  '0307582884',
#  '1943893179',
#  '1503950549',
#  '1433688670',
#  '0316408751',
#  '0141331976',
#  '141046900X',
#  '1451649320',
#  '1503938778',
#  'B01CIYURJE',
#  '0486789640',
#  '1492707872',
#  '6077547328',
#  '1910751243',
#  '0751565873',
#  '1503935183',
#  '1987987039',
#  '0425280101',
#  '1534640150',
#  '069289344X',
#  '147781826X',
#  '0765326264',
#  '1503943941',
#  '0340364777',
#  '1543644325',
#  '0062454943',
#  '0316339377',
#  '0349403759',
#  '0151015392',
#  '1477830049',
#  '0307967115',
#  '1442384433',
#  '1503935205',
#  '0316225908',
#  '0800788036',
#  '1635615372',
#  '1503939448',
#  '0385393997',
#  '1447260287',
#  '1979172846']

# %%
#Let's check how unbalanced the data is
book_reviews[book_reviews['asin'].isin(most_reviewed)].overall.value_counts(normalize=True)
# Out:
# 5    0.658635
# 4    0.191666
# 3    0.077627
# 1    0.036180
# 2    0.035889
# 0    0.000003
# Name: overall, dtype: float64

# %% [markdown]
# It appears very unbalanced

# %%
#creating multi-index pandas dataframe showing the number of reviews for each rating (1 to 5) for 'asin' numbers in the most_reviewed list
rating_dist=pd.DataFrame(book_reviews[book_reviews['asin'].isin(most_reviewed)].groupby(by='asin')['overall'].value_counts()).rename(columns={'overall':'count'})
rating_dist
# Out:
#                     count
# asin       overall
# 000711835X 5          888
#            4           85
#            3           44
#            1           32
#            2           24
# ...                   ...
# B01CIYURJE 5          352
#            4          113
#            3           90
#            2           52
#            1           48
#
# [1500 rows x 1 columns]

# %%
book_ratings=pd.DataFrame()
for i in most_reviewed:
    weighted_sum=0
    count=0
    for j in range(1,6):
        try:
            weighted_sum+=rating_dist.loc[i,j]*j  #multiplying each rating by number of times it was rated as such
            count+=rating_dist.loc[i,j]   #total count
        except:
            pass
    if (weighted_sum/count)[0]<3.5:   #calculating weighted average
        print([i,weighted_sum/count])
# Out:
# ['0062409883', count    3.453767
# Name: (0062409883, 1), dtype: float64]
# ['034551162X', count    2.682788
# Name: (034551162X, 1), dtype: float64]

# %%
book_reviews[(book_reviews['asin']=='034551162X')|(book_reviews['asin']=='0062409883')]
# Out:
#                asin  overall  verified  \
# 138779   0062409883        4     False
# 138859   0062409883        4      True
# 138884   0062409883        3      True
# 138892   0062409883        1     False
# 138914   0062409883        5     False
# ...             ...      ...       ...
# 722002   034551162X        3      True
# 722156   034551162X        2     False
# 722268   034551162X        4      True
# 3909376  0062409883        5      True
# 3977681  034551162X        4     False
#
#                                                 reviewText  reviewTime
# 138779   This book was a fascinating read. I re-read "T...  2015-07-27
# 138859                                  An important read.  2015-08-08
# 138884   Enjoyable. Not up to mockingbird standards but...  2015-08-14
# 138892   Save your money! This work was never meant to ...  2015-11-29
# 138914   We are all so smug in our hatred of racism but...  2015-08-22
# ...                                                    ...         ...
# 722002   Just an ok read. A bit of a struggle to get th...  2016-05-20
# 722156   First off, let me say that I have read a coupl...  2015-09-18
# 722268   It's been awhile since I read a Star Wars nove...  2015-09-18
# 3909376  If you loved To Kill a Mockingbird this is a m...  2018-04-24
# 3977681  Aftermath is the first novel in a three part s...  2018-04-17
#
# [3623 rows x 5 columns]

# %%
#We can also try to guess who the reviewer is based on writing style.

# %% [markdown]
# ---

# %% [markdown]
# ### Classification Task

# %%
book_reviews
# Out:
#                asin  overall  verified  \
# 0        0007444117        1     False
# 1        0007177437        4      True
# 2        0007327064        5      True
# 3        0030352401        3     False
# 4        000755236X        5      True
# ...             ...      ...       ...
# 5538557  1547843152        2      True
# 5538558  B01E6OZH5S        5      True
# 5538559  B00QSFOJ9E        5      True
# 5538560  1537644513        4      True
# 5538561  B01828NLTS        4     False
#
#                                                 reviewText  reviewTime
# 0        I was a huge fan when the Divergent series sta...  2016-09-03
# 1                                          Excellent read.  2015-09-16
# 2        From the very beginning.. I have loved Odd Tho...  2016-07-17
# 3        A good, easy, light-hearted read--however ther...  2016-03-02
# 4        As a fan of Daniel Silva's  books, especially ...  2017-03-07
# ...                                                    ...         ...
# 5538557                Returned...disappointed in content.  2018-06-27
# 5538558                                    good story book  2017-02-15
# 5538559                                         Great book  2015-09-01
# 5538560  Good read - I was hoping for the bad guys! Not...  2016-12-11
# 5538561       Beautiful hoodie great fabric but runs small  2016-09-16
#
# [5535445 rows x 5 columns]

# %%
gc.collect()
# Out:
# 22

# %%
reviews_ratings=book_reviews[['overall','reviewText']].copy(deep=True)    #selecting ratings and review text
reviews_ratings.to_csv('./data/reviews_and_ratings.csv',index=0)

# %%
#free-up memory by removing dataframes from memory and reloading necessary data from saved pickle file
del book_reviews
del reviews_ratings
gc.collect()
# Out:
# 22

# %%
reviews_ratings=pd.read_csv('./data/reviews_and_ratings.csv')

# %%
reviews_ratings
# Out:
#          overall                                         reviewText
# 0              1  I was a huge fan when the Divergent series sta...
# 1              4                                    Excellent read.
# 2              5  From the very beginning.. I have loved Odd Tho...
# 3              3  A good, easy, light-hearted read--however ther...
# 4              5  As a fan of Daniel Silva's  books, especially ...
# ...          ...                                                ...
# 5535440        2                Returned...disappointed in content.
# 5535441        5                                    good story book
# 5535442        5                                         Great book
# 5535443        4  Good read - I was hoping for the bad guys! Not...
# 5535444        4       Beautiful hoodie great fabric but runs small
#
# [5535445 rows x 2 columns]
